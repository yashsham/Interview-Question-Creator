# %%
print("ok!")
# Out:
# ok!

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# %%
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY

# %%
from langchain.document_loaders import PyPDFLoader

# %%
# %pwd
# Out:
# 'c:\\Users\\boybl\\Downloads\\AIQUESTIONCREATOR\\interview-question-creator'

# %%
# %cd ..
# Out:
# c:\Users\boybl\Downloads\AIQUESTIONCREATOR

# %%
# %pwd
# Out:
# 'c:\\Users\\boybl\\Downloads\\AIQUESTIONCREATOR'

# %%
# %cd Downloads
# Out:
# C:\Users\boybl\Downloads

# %%
# %cd AIQUESTIONCREATOR
# Out:
# C:\Users\boybl\Downloads\AIQUESTIONCREATOR

# %%
# %cd interview-question-creator
# Out:
# C:\Users\boybl\Downloads\AIQUESTIONCREATOR\interview-question-creator

# %%
file_path = "docs\sr. secondary history.pdf"
loader = PyPDFLoader(file_path)
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'producer': 'ilovepdf.com', 'creator': 'PyPDF', 'creationdate': '', 'moddate': '2018-06-19T13:29:37+02:00', 'source': 'docs\\sr. secondary history.pdf', 'total_pages': 521, 'page': 0, 'page_label': '1'}, page_content='HISTORY 1\nMODULE - 1\nAncient India\nUNDERSTANDING INDIAN HISTORY\n1\nNotes\nHistory is the study of past events. It helps us to understand those processes that\nenabled the early humans to successfully conquer their environment and develop the\npresent day civilizations. It is not just a study of battles and kings as is normally\nunderstood by some. It is an analysis of society, economy and cultural trends over a\nlong period as reflected in  available sources. A historian tries to evaluate different\nsituations over a long period and asks questions as to why certain events happened\nand what was their impact on society at large? Every new evidence or a fresh inter-\npretation of existing evidence by different scholars helps in enriching our knowle
# ...

# %%
len(data)
# Out:
# 521

# %%
question_gen = ""

for page in data:
    question_gen += page.page_content

# %%
question_gen
# Out:
# 'HISTORY 1\nMODULE - 1\nAncient India\nUNDERSTANDING INDIAN HISTORY\n1\nNotes\nHistory is the study of past events. It helps us to understand those processes that\nenabled the early humans to successfully conquer their environment and develop the\npresent day civilizations. It is not just a study of battles and kings as is normally\nunderstood by some. It is an analysis of society, economy and cultural trends over a\nlong period as reflected in  available sources. A historian tries to evaluate different\nsituations over a long period and asks questions as to why certain events happened\nand what was their impact on society at large? Every new evidence or a fresh inter-\npretation of existing evidence by different scholars helps in enriching our knowledge\nabout the past. A historian differentiates between fact and fiction. However , myths\nwhich are based on oral tradition of a society may contain memories of past happen-\nings. The historian’s job is to ascertain the fact through cr
# ...

# %%
pip install langchain transformers tiktoken
# Out:
# ...
#    ---------------------------------------- 0.0/894.0 kB ? eta -:--:--
#    ---------------------------------------- 894.0/894.0 kB 5.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.2 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.1 MB/s eta 0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# ...

# %%
jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
#   Cell In[37], line 1
#     jupyter labextension install @jupyter-widgets/jupyterlab-manager
#             ^
# SyntaxError: invalid syntax

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def count_tokens(text):
    return len(tokenizer.encode(text))

# Example usage
text = "This is a long piece of text..."
token_count = count_tokens(text)

# %%
text
# Out:
# 'This is a long piece of text...'

# %%
len(text)
# Out:
# 31

# %%
from langchain.docstore.document import Document

# %%
document_ques_gen = [Document(page_content = t) for t in text]

# %%
document_ques_gen
# Out:
# [Document(metadata={}, page_content='T'),
#  Document(metadata={}, page_content='h'),
#  Document(metadata={}, page_content='i'),
#  Document(metadata={}, page_content='s'),
#  Document(metadata={}, page_content=' '),
#  Document(metadata={}, page_content='i'),
#  Document(metadata={}, page_content='s'),
#  Document(metadata={}, page_content=' '),
#  Document(metadata={}, page_content='a'),
#  Document(metadata={}, page_content=' '),
#  Document(metadata={}, page_content='l'),
#  Document(metadata={}, page_content='o'),
#  Document(metadata={}, page_content='n'),
#  Document(metadata={}, page_content='g'),
#  Document(metadata={}, page_content=' '),
#  Document(metadata={}, page_content='p'),
#  Document(metadata={}, page_content='i'),
#  Document(metadata={}, page_content='e'),
#  Document(metadata={}, page_content='c'),
#  Document(metadata={}, page_content='e'),
#  Document(metadata={}, page_content=' '),
#  Document(metadata={}, page_content='o'),
# ...

# %%
type(document_ques_gen[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter_ques_gen = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = splitter_ques_gen.split_text(text)

# %%
len(text)
# Out:
# 31

# %%
# !pip install langchain-google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ---------------------- ----------------- 0.8/1.4 MB 1.9 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.0 MB/s eta 0:00:00
# ...
#
#   Attempting uninstall: google-ai-generativelanguage
#
#     Found existing installation: google-ai-generativelanguage 0.6.15
#
#    ------------- -------------------------- 1/3 [google-ai-generativelanguage]
#    ------------- -------------------------- 1/3 [google-ai-generativelanguage]
#    ------------- -------------------------- 1/3 [google-ai-generativelanguage]
#     Uninstalling google-ai-generativelanguage-0.6.15:
#    ------------- -------------------------- 1/3 [google-ai-generativelanguage]
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_ques_gen_pipeline = ChatGoogleGenerativeAI(
    model="gemini-pro",
    temperature=0.3
)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[59], line 3
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
# ----> 3 llm_ques_gen_pipeline = ChatGoogleGenerativeAI(
#       4     model="gemini-pro",
#       5     temperature=0.3
#       6 )
#
# File c:\Users\boybl\anaconda3\envs\interview\lib\site-packages\langchain_google_genai\chat_models.py:1179, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    1172         suggestion = (
#    1173             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1174         )
#    1175         logger.warning(
#    1176             f"Unexpected argument '{arg}' "
#    1177             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    1178         )
# -> 1179 super().__init__(**kwargs)
#
# ...
